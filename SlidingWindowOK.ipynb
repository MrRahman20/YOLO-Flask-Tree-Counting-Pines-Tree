# %% [markdown]
# Deteksi dan filtering(rasio green dan chm)

# %%
from ultralytics import YOLO
from PIL import Image
import geopandas as gpd
from shapely.geometry import Point
import os
import rasterio
import numpy as np
from sklearn.cluster import DBSCAN
import types

Image.MAX_IMAGE_PIXELS = None  # Menghilangkan batasan piksel

# Fungsi untuk memotong gambar menjadi beberapa window tanpa padding
def sliding_window(image, step_size, window_size):
    # Loop melalui koordinat y dengan langkah sebesar step_size
    for y in range(0, image.height, step_size):
        # Loop melalui koordinat x dengan langkah sebesar step_size
        for x in range(0, image.width, step_size):
            # Menghasilkan koordinat x, y, dan potongan gambar sesuai ukuran window_size
            yield x, y, image.crop((x, y, x + window_size[0], y + window_size[1]))

# Memuat model YOLOv8 yang sudah dilatih sebelumnya
model = YOLO('D:/KAMPUS/Model/.Model/contentv70/runs/detect/train/weights/best.pt')
# Menentukan path gambar yang akan diproses
image_path = 'D:/KAMPUS/Model/.Cliping/HutanPinus.png'
# Menentukan path file CHM yang akan digunakan
chm_path = 'D:/KAMPUS/Model/.CHM/CHM1.tif'
# Menentukan folder output untuk menyimpan hasil
output_folder = "D:/KAMPUS/Model/Export/ExportFilter"

# Membuka file gambar menggunakan rasterio
with rasterio.open(image_path) as src:
    # Membuka gambar menggunakan PIL
    image = Image.open(image_path)
    # Mendapatkan transformasi koordinat dari gambar
    transform = src.transform
    # Mendapatkan sistem referensi koordinat (CRS) dari gambar
    crs = src.crs

# Menentukan ukuran window tanpa padding
window_size = (2048, 2048)  # Ukuran window tanpa padding

# Menentukan ukuran langkah (step) untuk overlap antar window
step_size = 2048  # Overlap antar window

detected_points = []  # Inisialisasi list kosong untuk menyimpan titik-titik yang terdeteksi

with rasterio.open(chm_path) as chm_src:  # Membuka file CHM menggunakan rasterio
    chm_array = chm_src.read(1)  # Membaca data CHM sebagai array 2D
    height, width = chm_array.shape  # Mendapatkan tinggi dan lebar dari array CHM

    # Loop melalui setiap window yang dihasilkan oleh fungsi sliding_window
    for x, y, window in sliding_window(image, step_size, window_size):
        # Melakukan prediksi menggunakan model YOLO pada window dengan confidence threshold 0.10 dan IOU threshold 0.1
        results = model(window, conf=0.2, iou=0.1)
        # Mengubah hasil prediksi menjadi list jika hasilnya adalah generator
        results_list = list(results) if isinstance(results, types.GeneratorType) else results
        # Mendapatkan data bounding box dari hasil prediksi jika atribut 'data' ada
        boxes_data = results_list[0].boxes.data if hasattr(results_list[0].boxes, 'data') else []
        # Mengubah data bounding box menjadi list jika data tidak kosong
        boxes_list = boxes_data[:, :4].tolist() if boxes_data.nelement() else []

        # Loop melalui setiap bounding box dalam boxes_list
        for box in boxes_list:
            # Mendapatkan koordinat x1, y1, x2, y2 dari bounding box
            x1, y1, x2, y2 = box
            # Menghitung koordinat pusat bounding box dalam window
            center_x = (x1 + x2) / 2 + x
            center_y = (y1 + y2) / 2 + y
            # Mengubah koordinat pusat bounding box menjadi titik dalam sistem koordinat gambar
            point = Point(transform * (center_x, center_y))
            # Mendapatkan indeks baris dan kolom dari titik dalam array CHM
            row, col = chm_src.index(point.x, point.y)
            # Memeriksa apakah titik berada dalam batas array CHM dan nilai CHM di titik tersebut >= 1 meter
            if 0 <= row < height and 0 <= col < width and chm_array[row, col] >= 1:

                    # Menambahkan titik yang terdeteksi ke dalam list detected_points
                    detected_points.append(point)

def cluster_points(gdf, eps, min_samples):
    # Mengubah geometris dari GeoDataFrame menjadi array numpy dari koordinat x dan y
    coords = np.array(list(gdf.geometry.apply(lambda geom: (geom.x, geom.y))))
    # Melakukan clustering menggunakan algoritma DBSCAN dengan parameter eps dan min_samples
    db = DBSCAN(eps=eps, min_samples=min_samples).fit(coords)
    # Mendapatkan label hasil clustering
    labels = db.labels_

    # Membuat list dari titik-titik yang dikelompokkan berdasarkan label hasil clustering
    # Menggunakan koordinat rata-rata dari setiap kelompok (k) yang bukan noise (k != -1)
    clustered_points = [Point(coords[labels == k].mean(axis=0)) for k in set(labels) if k != -1]
    
    # Mengembalikan GeoDataFrame yang berisi titik-titik yang dikelompokkan dengan sistem koordinat yang sama dengan gdf
    return gpd.GeoDataFrame(geometry=clustered_points, crs=gdf.crs)

# Membuat GeoDataFrame dari list detected_points dengan sistem koordinat crs
gdf = gpd.GeoDataFrame(geometry=detected_points, crs=crs)
# Melakukan clustering pada GeoDataFrame dengan parameter eps dan min_samples
final_gdf = cluster_points(gdf, eps=2.46, min_samples=1)
# Menentukan path output untuk menyimpan file shapefile hasil clustering
final_output_path = os.path.join(output_folder, "Point_shapefile.shp")
# Menyimpan GeoDataFrame hasil clustering ke dalam file shapefile
final_gdf.to_file(final_output_path)

print("Proses prediksi dan clustering selesai!")
# Out:
# 0: 640x640 (no detections), 300.0ms
# Speed: 8.0ms preprocess, 300.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 297.0ms
# Speed: 6.0ms preprocess, 297.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 189 Pines-Trees, 287.0ms
# Speed: 5.0ms preprocess, 287.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 165 Pines-Trees, 277.0ms
# Speed: 6.0ms preprocess, 277.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 33 Pines-Trees, 309.0ms
# Speed: 5.0ms preprocess, 309.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 283.0ms
# Speed: 6.0ms preprocess, 283.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 278.0ms
# Speed: 8.0ms preprocess, 278.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 283.0ms
# Speed: 6.0ms preprocess, 283.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 295.0ms
# Speed: 7.0ms preprocess, 295.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 191 Pines-Trees, 308.0ms
# Speed: 5.0ms preprocess, 308.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 239 Pines-Trees, 298.0ms
# Speed: 7.0ms preprocess, 298.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 230 Pines-Trees, 260.0ms
# Speed: 5.0ms preprocess, 260.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 188 Pines-Trees, 282.0ms
# Speed: 5.0ms preprocess, 282.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 33 Pines-Trees, 254.0ms
# Speed: 7.0ms preprocess, 254.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 274.0ms
# Speed: 5.0ms preprocess, 274.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 67 Pines-Trees, 280.0ms
# Speed: 8.0ms preprocess, 280.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 231 Pines-Trees, 250.0ms
# Speed: 8.0ms preprocess, 250.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 229 Pines-Trees, 273.0ms
# Speed: 8.0ms preprocess, 273.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 226 Pines-Trees, 286.0ms
# Speed: 8.0ms preprocess, 286.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 215 Pines-Trees, 286.0ms
# Speed: 5.0ms preprocess, 286.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 80 Pines-Trees, 283.0ms
# Speed: 7.0ms preprocess, 283.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 315.0ms
# Speed: 6.0ms preprocess, 315.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 203 Pines-Trees, 277.0ms
# Speed: 8.0ms preprocess, 277.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 262 Pines-Trees, 291.0ms
# Speed: 6.0ms preprocess, 291.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 218 Pines-Trees, 271.0ms
# Speed: 5.0ms preprocess, 271.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 221 Pines-Trees, 376.0ms
# Speed: 7.0ms preprocess, 376.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 239 Pines-Trees, 306.0ms
# Speed: 7.0ms preprocess, 306.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 66 Pines-Trees, 293.0ms
# Speed: 8.0ms preprocess, 293.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 Pines-Trees, 273.0ms
# Speed: 5.0ms preprocess, 273.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 284 Pines-Trees, 301.0ms
# Speed: 5.0ms preprocess, 301.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 245 Pines-Trees, 270.0ms
# Speed: 5.0ms preprocess, 270.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 269 Pines-Trees, 258.0ms
# Speed: 6.0ms preprocess, 258.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 247 Pines-Trees, 282.0ms
# Speed: 5.0ms preprocess, 282.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 217 Pines-Trees, 261.0ms
# Speed: 5.0ms preprocess, 261.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 31 Pines-Trees, 260.0ms
# Speed: 5.0ms preprocess, 260.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 68 Pines-Trees, 257.0ms
# Speed: 8.0ms preprocess, 257.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 28 Pines-Trees, 273.0ms
# Speed: 7.0ms preprocess, 273.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 300 Pines-Trees, 292.0ms
# Speed: 5.0ms preprocess, 292.0ms inference, 9.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 288 Pines-Trees, 271.0ms
# Speed: 5.0ms preprocess, 271.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 155 Pines-Trees, 270.0ms
# Speed: 7.0ms preprocess, 270.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 22 Pines-Trees, 290.0ms
# Speed: 6.0ms preprocess, 290.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 313.0ms
# Speed: 8.0ms preprocess, 313.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 159 Pines-Trees, 293.0ms
# Speed: 5.0ms preprocess, 293.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 127 Pines-Trees, 287.0ms
# Speed: 7.0ms preprocess, 287.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 52 Pines-Trees, 285.0ms
# Speed: 5.0ms preprocess, 285.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 57 Pines-Trees, 282.0ms
# Speed: 5.0ms preprocess, 282.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Pines-Trees, 274.0ms
# Speed: 5.0ms preprocess, 274.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 278.0ms
# Speed: 6.0ms preprocess, 278.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 278.0ms
# Speed: 5.0ms preprocess, 278.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 117 Pines-Trees, 293.0ms
# Speed: 5.0ms preprocess, 293.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 269 Pines-Trees, 1 null, 287.0ms
# Speed: 7.0ms preprocess, 287.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 224 Pines-Trees, 275.0ms
# Speed: 5.0ms preprocess, 275.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 282.0ms
# Speed: 5.0ms preprocess, 282.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 274.0ms
# Speed: 8.0ms preprocess, 274.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 261.0ms
# Speed: 5.0ms preprocess, 261.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 283.0ms
# Speed: 5.0ms preprocess, 283.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 36 Pines-Trees, 256.0ms
# Speed: 5.0ms preprocess, 256.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 211 Pines-Trees, 294.0ms
# Speed: 6.0ms preprocess, 294.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 253 Pines-Trees, 274.0ms
# Speed: 5.0ms preprocess, 274.0ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 44 Pines-Trees, 290.0ms
# Speed: 6.0ms preprocess, 290.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 274.0ms
# Speed: 7.0ms preprocess, 274.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 298.0ms
# Speed: 5.0ms preprocess, 298.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 295.0ms
# Speed: 5.0ms preprocess, 295.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 300.0ms
# Speed: 8.0ms preprocess, 300.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 Pines-Trees, 291.0ms
# Speed: 5.0ms preprocess, 291.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 145 Pines-Trees, 287.0ms
# Speed: 5.0ms preprocess, 287.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 28 Pines-Trees, 329.0ms
# Speed: 8.0ms preprocess, 329.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 294.0ms
# Speed: 6.0ms preprocess, 294.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 302.0ms
# Speed: 8.0ms preprocess, 302.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 295.0ms
# Speed: 6.0ms preprocess, 295.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 278.0ms
# Speed: 8.0ms preprocess, 278.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 309.0ms
# Speed: 8.0ms preprocess, 309.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Pines-Tree, 297.0ms
# Speed: 8.0ms preprocess, 297.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 Pines-Trees, 312.0ms
# Speed: 6.0ms preprocess, 312.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 323.0ms
# Speed: 8.0ms preprocess, 323.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 319.0ms
# Speed: 8.0ms preprocess, 319.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 297.0ms
# Speed: 6.0ms preprocess, 297.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Proses prediksi dan clustering selesai!

# %% [markdown]
# Deteksi dan filtering chm

# %%
from ultralytics import YOLO
from PIL import Image
import geopandas as gpd
from shapely.geometry import Point
import os
import rasterio
import numpy as np
from sklearn.cluster import DBSCAN
import types

Image.MAX_IMAGE_PIXELS = None  # Menghilangkan batasan piksel

# Fungsi untuk memotong gambar menjadi beberapa window tanpa padding
def sliding_window(image, step_size, window_size):
    # Loop melalui koordinat y dengan langkah sebesar step_size
    for y in range(0, image.height, step_size):
        # Loop melalui koordinat x dengan langkah sebesar step_size
        for x in range(0, image.width, step_size):
            # Menghasilkan koordinat x, y, dan potongan gambar sesuai ukuran window_size
            yield x, y, image.crop((x, y, x + window_size[0], y + window_size[1]))

# Memuat model YOLOv8 yang sudah dilatih sebelumnya
model = YOLO('D:/KAMPUS/Model/.Model/contentv70/runs/detect/train/weights/best.pt')
# Menentukan path gambar yang akan diproses
image_path = 'D:/KAMPUS/Model/.Cliping/HutanPinus.png'
# Menentukan path file CHM yang akan digunakan
chm_path = 'D:/KAMPUS/Model/.CHM/CHM1.tif'
# Menentukan folder output untuk menyimpan hasil
output_folder = "D:/KAMPUS/Model/Export/ExportTanpaFilter"

# Membuka file gambar menggunakan rasterio
with rasterio.open(image_path) as src:
    # Membuka gambar menggunakan PIL
    image = Image.open(image_path)
    # Mendapatkan transformasi koordinat dari gambar
    transform = src.transform
    # Mendapatkan sistem referensi koordinat (CRS) dari gambar
    crs = src.crs

# Menentukan ukuran window tanpa padding
window_size = (2048, 2048)  # Ukuran window tanpa padding

# Menentukan ukuran langkah (step) untuk overlap antar window
step_size = 2048  # Overlap antar window

detected_points = []  # Inisialisasi list kosong untuk menyimpan titik-titik yang terdeteksi

with rasterio.open(chm_path) as chm_src:  # Membuka file CHM menggunakan rasterio
    chm_array = chm_src.read(1)  # Membaca data CHM sebagai array 2D
    height, width = chm_array.shape  # Mendapatkan tinggi dan lebar dari array CHM

    # Loop melalui setiap window yang dihasilkan oleh fungsi sliding_window
    for x, y, window in sliding_window(image, step_size, window_size):
        # Melakukan prediksi menggunakan model YOLO pada window dengan confidence threshold 0.10 dan IOU threshold 0.1
        results = model(window, conf=0.2, iou=0.1)
        # Mengubah hasil prediksi menjadi list jika hasilnya adalah generator
        results_list = list(results) if isinstance(results, types.GeneratorType) else results
        # Mendapatkan data bounding box dari hasil prediksi jika atribut 'data' ada
        boxes_data = results_list[0].boxes.data if hasattr(results_list[0].boxes, 'data') else []
        # Mengubah data bounding box menjadi list jika data tidak kosong
        boxes_list = boxes_data[:, :4].tolist() if boxes_data.nelement() else []

        # Loop melalui setiap bounding box dalam boxes_list
        for box in boxes_list:
            # Mendapatkan koordinat x1, y1, x2, y2 dari bounding box
            x1, y1, x2, y2 = box
            # Menghitung koordinat pusat bounding box dalam window
            center_x = (x1 + x2) / 2 + x
            center_y = (y1 + y2) / 2 + y
            # Mengubah koordinat pusat bounding box menjadi titik dalam sistem koordinat gambar
            point = Point(transform * (center_x, center_y))
            # Mendapatkan indeks baris dan kolom dari titik dalam array CHM
            row, col = chm_src.index(point.x, point.y)
            # Memeriksa apakah titik berada dalam batas array CHM dan nilai CHM di titik tersebut >= 1 meter
            if 0 <= row < height and 0 <= col < width and chm_array[row, col] >= 0:
                    # Menambahkan titik yang terdeteksi ke dalam list detected_points
                    detected_points.append(point)

def cluster_points(gdf, eps, min_samples):
    # Mengubah geometris dari GeoDataFrame menjadi array numpy dari koordinat x dan y
    coords = np.array(list(gdf.geometry.apply(lambda geom: (geom.x, geom.y))))
    # Melakukan clustering menggunakan algoritma DBSCAN dengan parameter eps dan min_samples
    db = DBSCAN(eps=eps, min_samples=min_samples).fit(coords)
    # Mendapatkan label hasil clustering
    labels = db.labels_

    # Membuat list dari titik-titik yang dikelompokkan berdasarkan label hasil clustering
    # Menggunakan koordinat rata-rata dari setiap kelompok (k) yang bukan noise (k != -1)
    clustered_points = [Point(coords[labels == k].mean(axis=0)) for k in set(labels) if k != -1]
    
    # Mengembalikan GeoDataFrame yang berisi titik-titik yang dikelompokkan dengan sistem koordinat yang sama dengan gdf
    return gpd.GeoDataFrame(geometry=clustered_points, crs=gdf.crs)

# Membuat GeoDataFrame dari list detected_points dengan sistem koordinat crs
gdf = gpd.GeoDataFrame(geometry=detected_points, crs=crs)
# Melakukan clustering pada GeoDataFrame dengan parameter eps dan min_samples
final_gdf = cluster_points(gdf, eps=2.46, min_samples=1)
# Menentukan path output untuk menyimpan file shapefile hasil clustering
final_output_path = os.path.join(output_folder, "Point_shapefile.shp")
# Menyimpan GeoDataFrame hasil clustering ke dalam file shapefile
final_gdf.to_file(final_output_path)

print("Proses prediksi dan clustering selesai!")
# Out:
# 0: 640x640 (no detections), 340.0ms
# Speed: 7.0ms preprocess, 340.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 352.0ms
# Speed: 8.0ms preprocess, 352.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 189 Pines-Trees, 330.0ms
# Speed: 6.0ms preprocess, 330.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 165 Pines-Trees, 327.0ms
# Speed: 6.0ms preprocess, 327.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 33 Pines-Trees, 341.0ms
# Speed: 8.0ms preprocess, 341.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 316.0ms
# Speed: 5.0ms preprocess, 316.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 300.0ms
# Speed: 9.0ms preprocess, 300.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 303.0ms
# Speed: 5.0ms preprocess, 303.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 333.0ms
# Speed: 9.0ms preprocess, 333.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 191 Pines-Trees, 338.0ms
# Speed: 8.0ms preprocess, 338.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 239 Pines-Trees, 324.0ms
# Speed: 5.0ms preprocess, 324.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 230 Pines-Trees, 304.0ms
# Speed: 8.0ms preprocess, 304.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 188 Pines-Trees, 301.0ms
# Speed: 5.0ms preprocess, 301.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 33 Pines-Trees, 289.0ms
# Speed: 5.0ms preprocess, 289.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 290.0ms
# Speed: 5.0ms preprocess, 290.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 67 Pines-Trees, 303.0ms
# Speed: 6.0ms preprocess, 303.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 231 Pines-Trees, 282.0ms
# Speed: 7.0ms preprocess, 282.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 229 Pines-Trees, 308.0ms
# Speed: 7.0ms preprocess, 308.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 226 Pines-Trees, 276.0ms
# Speed: 8.0ms preprocess, 276.0ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 215 Pines-Trees, 301.0ms
# Speed: 8.0ms preprocess, 301.0ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 80 Pines-Trees, 287.0ms
# Speed: 6.0ms preprocess, 287.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 266.0ms
# Speed: 5.0ms preprocess, 266.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 203 Pines-Trees, 300.0ms
# Speed: 5.0ms preprocess, 300.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 262 Pines-Trees, 285.0ms
# Speed: 5.0ms preprocess, 285.0ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 218 Pines-Trees, 292.0ms
# Speed: 6.0ms preprocess, 292.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 221 Pines-Trees, 292.0ms
# Speed: 5.0ms preprocess, 292.0ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 239 Pines-Trees, 290.0ms
# Speed: 5.0ms preprocess, 290.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 66 Pines-Trees, 297.0ms
# Speed: 6.0ms preprocess, 297.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 Pines-Trees, 302.0ms
# Speed: 6.0ms preprocess, 302.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 284 Pines-Trees, 298.0ms
# Speed: 6.0ms preprocess, 298.0ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 245 Pines-Trees, 304.0ms
# Speed: 5.0ms preprocess, 304.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 269 Pines-Trees, 298.0ms
# Speed: 8.0ms preprocess, 298.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 247 Pines-Trees, 306.0ms
# Speed: 6.0ms preprocess, 306.0ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 217 Pines-Trees, 284.0ms
# Speed: 8.0ms preprocess, 284.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 31 Pines-Trees, 280.0ms
# Speed: 5.0ms preprocess, 280.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 68 Pines-Trees, 281.0ms
# Speed: 5.0ms preprocess, 281.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 28 Pines-Trees, 340.0ms
# Speed: 8.0ms preprocess, 340.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 300 Pines-Trees, 312.0ms
# Speed: 5.0ms preprocess, 312.0ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 288 Pines-Trees, 285.0ms
# Speed: 7.0ms preprocess, 285.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 155 Pines-Trees, 292.0ms
# Speed: 5.0ms preprocess, 292.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 22 Pines-Trees, 294.0ms
# Speed: 5.0ms preprocess, 294.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 311.0ms
# Speed: 7.0ms preprocess, 311.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 159 Pines-Trees, 313.0ms
# Speed: 5.0ms preprocess, 313.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 127 Pines-Trees, 290.0ms
# Speed: 5.0ms preprocess, 290.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 52 Pines-Trees, 281.0ms
# Speed: 5.0ms preprocess, 281.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 57 Pines-Trees, 268.0ms
# Speed: 5.0ms preprocess, 268.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Pines-Trees, 254.0ms
# Speed: 5.0ms preprocess, 254.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 257.0ms
# Speed: 5.0ms preprocess, 257.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 275.0ms
# Speed: 8.0ms preprocess, 275.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 117 Pines-Trees, 263.0ms
# Speed: 6.0ms preprocess, 263.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 269 Pines-Trees, 1 null, 291.0ms
# Speed: 8.0ms preprocess, 291.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 224 Pines-Trees, 325.0ms
# Speed: 5.0ms preprocess, 325.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 275.0ms
# Speed: 5.0ms preprocess, 275.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 301.0ms
# Speed: 5.0ms preprocess, 301.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 296.0ms
# Speed: 5.0ms preprocess, 296.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 292.0ms
# Speed: 4.0ms preprocess, 292.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 36 Pines-Trees, 226.0ms
# Speed: 5.0ms preprocess, 226.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 211 Pines-Trees, 289.0ms
# Speed: 7.0ms preprocess, 289.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 253 Pines-Trees, 284.0ms
# Speed: 7.0ms preprocess, 284.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 44 Pines-Trees, 293.0ms
# Speed: 5.0ms preprocess, 293.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 285.0ms
# Speed: 7.0ms preprocess, 285.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 277.0ms
# Speed: 5.0ms preprocess, 277.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 304.0ms
# Speed: 9.0ms preprocess, 304.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 268.0ms
# Speed: 8.0ms preprocess, 268.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 8 Pines-Trees, 252.0ms
# Speed: 4.0ms preprocess, 252.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 145 Pines-Trees, 293.0ms
# Speed: 7.0ms preprocess, 293.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 28 Pines-Trees, 254.0ms
# Speed: 8.0ms preprocess, 254.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 272.0ms
# Speed: 5.0ms preprocess, 272.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 300.0ms
# Speed: 5.0ms preprocess, 300.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 285.0ms
# Speed: 6.0ms preprocess, 285.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 270.0ms
# Speed: 4.0ms preprocess, 270.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 239.0ms
# Speed: 5.0ms preprocess, 239.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Pines-Tree, 296.0ms
# Speed: 5.0ms preprocess, 296.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 Pines-Trees, 291.0ms
# Speed: 5.0ms preprocess, 291.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 272.0ms
# Speed: 5.0ms preprocess, 272.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 287.0ms
# Speed: 6.0ms preprocess, 287.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 273.0ms
# Speed: 5.0ms preprocess, 273.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Proses prediksi dan clustering selesai!
